# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('train logistic new.csv')

# %%
df
# Out:
#        trip_duration  distance_traveled  num_of_passengers    fare  tip  \
# 0                748               2.75                  1   75.00   24
# 1               1187               3.43                  1  105.00   24
# 2                730               3.12                  1   71.25    0
# 3                671               5.63                  3   90.00    0
# 4                329               2.09                  1   45.00   12
# ...              ...                ...                ...     ...  ...
# 19994            496               2.25                  6   56.25    0
# 19995            317               1.45                  1   41.25   14
# 19996            759               2.12                  1   56.25    0
# 19997            535               2.19                  1   56.25    0
# 19998            589               3.35                  2   67.50   15
#
#        miscellaneous_fees  total_fare  surge_applied
# ...

# %%
df.head()
# Out:
#    trip_duration  distance_traveled  num_of_passengers    fare  tip  \
# 0            748               2.75                  1   75.00   24
# 1           1187               3.43                  1  105.00   24
# 2            730               3.12                  1   71.25    0
# 3            671               5.63                  3   90.00    0
# 4            329               2.09                  1   45.00   12
#
#    miscellaneous_fees  total_fare  surge_applied
# 0               6.300     105.300              0
# 1              13.200     142.200              0
# 2              26.625      97.875              1
# 3               9.750      99.750              0
# 4              13.200      70.200              0

# %%
df.tail()
# Out:
#        trip_duration  distance_traveled  num_of_passengers   fare  tip  \
# 19994            496               2.25                  6  56.25    0
# 19995            317               1.45                  1  41.25   14
# 19996            759               2.12                  1  56.25    0
# 19997            535               2.19                  1  56.25    0
# 19998            589               3.35                  2  67.50   15
#
#        miscellaneous_fees  total_fare  surge_applied
# 19994               6.000      62.250              0
# 19995               5.875      61.125              0
# 19996               9.750      66.000              0
# 19997              13.500      69.750              0
# 19998               5.700      88.200              0

# %%
df.min()
# Out:
# trip_duration         0.00
# distance_traveled     0.02
# num_of_passengers     0.00
# fare                  0.00
# tip                   0.00
# miscellaneous_fees    0.00
# total_fare            0.00
# surge_applied         0.00
# dtype: float64

# %%
df.max()
# Out:
# trip_duration         86309.000
# distance_traveled       108.920
# num_of_passengers         8.000
# fare                   1657.500
# tip                     950.000
# miscellaneous_fees      230.875
# total_fare             1659.750
# surge_applied             1.000
# dtype: float64

# %%
df.shape
# Out:
# (19999, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19999 entries, 0 to 19998
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   trip_duration       19999 non-null  int64
#  1   distance_traveled   19999 non-null  float64
#  2   num_of_passengers   19999 non-null  int64
#  3   fare                19999 non-null  float64
#  4   tip                 19999 non-null  int64
#  5   miscellaneous_fees  19999 non-null  float64
#  6   total_fare          19999 non-null  float64
#  7   surge_applied       19999 non-null  int64
# dtypes: float64(4), int64(4)
# memory usage: 1.2 MB

# %%
df.describe()
# Out:
#        trip_duration  distance_traveled  num_of_passengers          fare  \
# count   19999.000000       19999.000000       19999.000000  19999.000000
# mean     1163.876494           4.783308           1.289414     99.577315
# std      4703.340653           4.962265           0.928886     79.972935
# min         0.000000           0.020000           0.000000      0.000000
# 25%       442.000000           1.930000           1.000000     52.500000
# 50%       701.000000           3.190000           1.000000     75.000000
# 75%      1099.000000           5.710000           1.000000    116.250000
# max     86309.000000         108.920000           8.000000   1657.500000
#
#                 tip  miscellaneous_fees   total_fare  surge_applied
# count  19999.000000        19999.000000  19999.00000   19999.000000
# mean      13.165008           15.126646    127.86897       0.279964
# std       20.946559           12.616910     93.96945       0.448992
# ...

# %%
df.isnull().sum()
# Out:
# trip_duration         0
# distance_traveled     0
# num_of_passengers     0
# fare                  0
# tip                   0
# miscellaneous_fees    0
# total_fare            0
# surge_applied         0
# dtype: int64

# %%
num_duplicates = df.duplicated().sum()
total_rows = len(df)
percentage_duplicates = (num_duplicates / total_rows) * 100

print(f'Total number of duplicated rows: {num_duplicates}')
print(f'Percentage of duplicated rows: {percentage_duplicates:.2f}%')
# Out:
# Total number of duplicated rows: 57
# Percentage of duplicated rows: 0.29%

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#        trip_duration  distance_traveled  num_of_passengers    fare  tip  \
# 0                748               2.75                  1   75.00   24
# 1               1187               3.43                  1  105.00   24
# 2                730               3.12                  1   71.25    0
# 3                671               5.63                  3   90.00    0
# 4                329               2.09                  1   45.00   12
# ...              ...                ...                ...     ...  ...
# 19994            496               2.25                  6   56.25    0
# 19995            317               1.45                  1   41.25   14
# 19996            759               2.12                  1   56.25    0
# 19997            535               2.19                  1   56.25    0
# 19998            589               3.35                  2   67.50   15
#
#        miscellaneous_fees  total_fare  surge_applied
# ...

# %%
q1=df['num_of_passengers'].quantile(0.25)
q3=df['num_of_passengers'].quantile(0.75)
iqr=q3-q1
threshold=1.5

admit_outliers=df[(df['num_of_passengers']<q1-threshold*iqr) | (df['num_of_passengers'] > q3+threshold*iqr)]
df=df.drop(admit_outliers.index)
admit_outliers
# Out:
#        trip_duration  distance_traveled  num_of_passengers    fare  tip  \
# 3                671               5.63                  3   90.00    0
# 10             84305               4.94                  2  116.25   29
# 14               234               1.61                  0   37.50    0
# 19               773               3.41                  2   75.00    9
# 23              1617               3.23                  6  123.75    8
# ...              ...                ...                ...     ...  ...
# 19969            178               1.37                  2   33.75    8
# 19982            355               1.24                  2   45.00   15
# 19988            566               1.32                  2   52.50    0
# 19994            496               2.25                  6   56.25    0
# 19998            589               3.35                  2   67.50   15
#
#        miscellaneous_fees  total_fare  surge_applied
# ...

# %%
# Calculate the percentage of outliers
num_outliers = len(admit_outliers)
total_rows = len(df)
percentage_outliers = (num_outliers / (total_rows + num_outliers)) * 100

print(f'Total number of outliers: {num_outliers}')
print(f'Percentage of outliers: {percentage_outliers:.2f}%')
# Out:
# Total number of outliers: 2889
# Percentage of outliers: 14.49%

# %%
df.reset_index()
# Out:
#        index  trip_duration  distance_traveled  num_of_passengers    fare  \
# 0          0            748               2.75                  1   75.00
# 1          1           1187               3.43                  1  105.00
# 2          2            730               3.12                  1   71.25
# 3          4            329               2.09                  1   45.00
# 4          5            355               1.74                  1   45.00
# ...      ...            ...                ...                ...     ...
# 17048  19992           1367               5.46                  1  123.75
# 17049  19993            309               1.93                  1   45.00
# 17050  19995            317               1.45                  1   41.25
# 17051  19996            759               2.12                  1   56.25
# 17052  19997            535               2.19                  1   56.25
#
#        tip  miscellaneous_fees  total_fare  surge_applied
# ...

# %%
df
# Out:
#        trip_duration  distance_traveled  num_of_passengers    fare  tip  \
# 0                748               2.75                  1   75.00   24
# 1               1187               3.43                  1  105.00   24
# 2                730               3.12                  1   71.25    0
# 4                329               2.09                  1   45.00   12
# 5                355               1.74                  1   45.00    0
# ...              ...                ...                ...     ...  ...
# 19992           1367               5.46                  1  123.75    0
# 19993            309               1.93                  1   45.00    0
# 19995            317               1.45                  1   41.25   14
# 19996            759               2.12                  1   56.25    0
# 19997            535               2.19                  1   56.25    0
#
#        miscellaneous_fees  total_fare  surge_applied
# ...

# %%
import seaborn as sns
sns.boxplot(x='trip_duration',data=df)
# Out:
# <Axes: xlabel='trip_duration'>

# %%
sns.boxplot(x='distance_traveled',data=df)
# Out:
# <Axes: xlabel='distance_traveled'>

# %%
sns.boxplot(x='num_of_passengers',data=df)
# Out:
# <Axes: xlabel='num_of_passengers'>

# %%
sns.boxplot(x='fare',data=df)
# Out:
# <Axes: xlabel='fare'>

# %%
sns.boxplot(x='tip',data=df)
# Out:
# <Axes: xlabel='tip'>

# %%
sns.boxplot(x='miscellaneous_fees',data=df)
# Out:
# <Axes: xlabel='miscellaneous_fees'>

# %%
import seaborn as sns
sns.boxplot(x='total_fare',data=df)
# Out:
# <Axes: xlabel='total_fare'>

# %%
sns.boxplot(x='surge_applied',data=df)
# Out:
# <Axes: xlabel='surge_applied'>

# %%
sns.pairplot(df,hue='surge_applied')
# Out:
# C:\Users\RISHABH\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\RISHABH\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\RISHABH\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
sns.regplot(x='trip_duration',y='surge_applied',data=df,color='r')
# Out:
# <Axes: xlabel='trip_duration', ylabel='surge_applied'>

# %%
sns.regplot(x='distance_traveled',y='surge_applied',data=df,color='r')
# Out:
# <Axes: xlabel='distance_traveled', ylabel='surge_applied'>

# %%
sns.regplot(x='num_of_passengers',y='surge_applied',data=df,color='r')
# Out:
# <Axes: xlabel='num_of_passengers', ylabel='surge_applied'>

# %%
sns.regplot(x='fare',y='surge_applied',data=df,color='r')
# Out:
# <Axes: xlabel='fare', ylabel='surge_applied'>

# %%
sns.regplot(x='tip',y='surge_applied',data=df,color='r')
# Out:
# <Axes: xlabel='tip', ylabel='surge_applied'>

# %%
sns.regplot(x='miscellaneous_fees',y='surge_applied',data=df,color='r')
# Out:
# <Axes: xlabel='miscellaneous_fees', ylabel='surge_applied'>

# %%
sns.regplot(x='total_fare',y='surge_applied',data=df,color='r')
# Out:
# <Axes: xlabel='total_fare', ylabel='surge_applied'>

# %%
x=df.iloc[:,:-1]
y=df.iloc[:,-1]

# %%
x
# Out:
#        trip_duration  distance_traveled  num_of_passengers    fare  tip  \
# 0                748               2.75                  1   75.00   24
# 1               1187               3.43                  1  105.00   24
# 2                730               3.12                  1   71.25    0
# 4                329               2.09                  1   45.00   12
# 5                355               1.74                  1   45.00    0
# ...              ...                ...                ...     ...  ...
# 19992           1367               5.46                  1  123.75    0
# 19993            309               1.93                  1   45.00    0
# 19995            317               1.45                  1   41.25   14
# 19996            759               2.12                  1   56.25    0
# 19997            535               2.19                  1   56.25    0
#
#        miscellaneous_fees  total_fare
# 0                   6.300     105.300
# ...

# %%
y
# Out:
# 0        0
# 1        0
# 2        1
# 4        0
# 5        1
#         ..
# 19992    0
# 19993    0
# 19995    0
# 19996    0
# 19997    0
# Name: surge_applied, Length: 17053, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
import numpy as np
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state=43)

# %%
x_train
# Out:
#        trip_duration  distance_traveled  num_of_passengers    fare  tip  \
# 13410            615               2.11                  1   60.00   13
# 14408           1110               4.23                  1  101.25    0
# 10993            883               3.52                  1   86.25   19
# 7609             238               0.92                  1   33.75    0
# 18471            781               4.15                  1   82.50   27
# ...              ...                ...                ...     ...  ...
# 6523             254               0.85                  1   33.75    0
# 19142            268               1.64                  1   41.25    0
# 6247             429               1.63                  1   48.75    0
# 9390             502               2.37                  1   56.25    0
# 16583            475               1.53                  1   52.50   15
#
#        miscellaneous_fees  total_fare
# 13410              26.600      99.600
# ...

# %%
y_train
# Out:
# 13410    1
# 14408    0
# 10993    0
# 7609     0
# 18471    1
#         ..
# 6523     0
# 19142    0
# 6247     0
# 9390     0
# 16583    0
# Name: surge_applied, Length: 13642, dtype: int64

# %% [markdown]
# # MultiLinear Classification

# %%
#model building 
from sklearn.linear_model import LogisticRegression

# %%
classifier = LogisticRegression()

# %%
classifier
# Out:
# LogisticRegression()

# %%
from sklearn.model_selection import GridSearchCV

parameter = {'penalty':['l1','l2','elasticnet'],
             'C':[1,2,3,4,5,6,10,20,30,40,50],
             'max_iter': [100,200,300]}

# %%
classifier_regressor = GridSearchCV(classifier,
                                    param_grid = parameter,
                                    cv=5)

# %%
classifier_regressor.fit(x_train,y_train)
# Out:
# C:\Users\RISHABH\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\RISHABH\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
print(classifier_regressor.best_params_)
# Out:
# {'C': 2, 'max_iter': 200, 'penalty': 'l2'}

# %%
print(classifier_regressor.best_score_)
# Out:
# 0.9688463704170156

# %%
#prediction 
classifier_regressor.predict(x_test)
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
y_pred = classifier_regressor.predict(x_test)
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
#accuracy score
from sklearn.metrics import accuracy_score,classification_report

# %%
score = accuracy_score(y_pred,y_test)
print(score)
# Out:
# 0.9736147757255936

# %%
print(classification_report(y_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98      2382
#            1       0.98      0.93      0.96      1029
#
#     accuracy                           0.97      3411
#    macro avg       0.97      0.96      0.97      3411
# weighted avg       0.97      0.97      0.97      3411

# %%
classifier_regressor.predict([[329,2.09,1,45.00,12,13.200,70.200]])
# Out:
# C:\Users\RISHABH\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([0], dtype=int64)

# %% [markdown]
# # DecisionTreeClassifier

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import StandardScaler

# %%
# post pruning technique
treemodel=DecisionTreeClassifier(max_depth=2)

# %%
treemodel.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=2)

# %%
# constructing tree

import matplotlib.pyplot as plt
from sklearn import tree
plt.figure(figsize=(15,10))

tree.plot_tree(treemodel,filled=True)
# Out:
# [Text(0.4, 0.8333333333333334, 'x[5] <= 21.6\ngini = 0.404\nsamples = 13642\nvalue = [9813, 3829]'),
#  Text(0.2, 0.5, 'gini = 0.0\nsamples = 9518\nvalue = [9518, 0]'),
#  Text(0.6, 0.5, 'x[5] <= 34.938\ngini = 0.133\nsamples = 4124\nvalue = [295, 3829]'),
#  Text(0.4, 0.16666666666666666, 'gini = 0.014\nsamples = 3784\nvalue = [26, 3758]'),
#  Text(0.8, 0.16666666666666666, 'gini = 0.33\nsamples = 340\nvalue = [269, 71]')]

# %%
treemodel=DecisionTreeClassifier()
treemodel
# Out:
# DecisionTreeClassifier()

# %%
treemodel.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
# Constructing Tree

from sklearn import tree

plt.figure(figsize=(15,10))
tree.plot_tree(treemodel,filled=True)
# Out:
# [Text(0.5046296296296297, 0.95, 'x[5] <= 21.6\ngini = 0.404\nsamples = 13642\nvalue = [9813, 3829]'),
#  Text(0.4675925925925926, 0.85, 'gini = 0.0\nsamples = 9518\nvalue = [9518, 0]'),
#  Text(0.5416666666666666, 0.85, 'x[5] <= 34.938\ngini = 0.133\nsamples = 4124\nvalue = [295, 3829]'),
#  Text(0.3055555555555556, 0.75, 'x[5] <= 27.587\ngini = 0.014\nsamples = 3784\nvalue = [26, 3758]'),
#  Text(0.18518518518518517, 0.65, 'x[4] <= 84.5\ngini = 0.002\nsamples = 2414\nvalue = [2, 2412]'),
#  Text(0.1111111111111111, 0.55, 'x[4] <= 0.5\ngini = 0.001\nsamples = 2402\nvalue = [1, 2401]'),
#  Text(0.07407407407407407, 0.45, 'x[1] <= 5.73\ngini = 0.003\nsamples = 639\nvalue = [1, 638]'),
#  Text(0.037037037037037035, 0.35, 'gini = 0.0\nsamples = 347\nvalue = [0, 347]'),
#  Text(0.1111111111111111, 0.35, 'x[1] <= 5.77\ngini = 0.007\nsamples = 292\nvalue = [1, 291]'),
#  Text(0.07407407407407407, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
# ...

# %%
# prdiction
y_pred=treemodel.predict(x_test)

# %%
from sklearn.metrics import accuracy_score,classification_report

# %%
score=accuracy_score(y_pred,y_test)
print(score)
# Out:
# 0.9988273233655819

# %%
# prepruning
parameter_grid = {
    'criterion': ['gini', 'entropy', 'log_loss'],
    'splitter': ['best', 'random'],
    'max_depth': [1, 2, 3, 4, 5],
    'max_features': [None, 'sqrt', 'log2'],
    'ccp_alpha': [0, 0.1, 0.01, 0.001, 1, 2, 3, 4, 5, 6, 7]
}

# %%
from sklearn.model_selection import GridSearchCV

# %%
treemodel = DecisionTreeClassifier(random_state=42)
cv=GridSearchCV(treemodel, param_grid=parameter_grid, cv=5, scoring='accuracy', n_jobs=-1)

# %%
cv.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(random_state=42), n_jobs=-1,
#              param_grid={'ccp_alpha': [0, 0.1, 0.01, 0.001, 1, 2, 3, 4, 5, 6,
#                                        7],
#                          'criterion': ['gini', 'entropy', 'log_loss'],
#                          'max_depth': [1, 2, 3, 4, 5],
#                          'max_features': [None, 'sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              scoring='accuracy')

# %%
cv.best_params_
# Out:
# {'ccp_alpha': 0.001,
#  'criterion': 'entropy',
#  'max_depth': 5,
#  'max_features': None,
#  'splitter': 'best'}

# %%
cv.predict(x_test)
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
y_pred=cv.predict(x_test)

# %%
from sklearn.metrics import accuracy_score,classification_report

# %%
score=accuracy_score(y_pred,y_test)

# %%
print("Accuracy score: %0.5f" % score)
# Out:
# Accuracy score: 0.99941

# %%
cv.predict([[329,2.09,1,45.00,12,13.200,70.200]])
# Out:
# C:\Users\RISHABH\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([0], dtype=int64)

# %% [markdown]
# # Random Forest

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
import time

# Flatten the class labels
y_train = y_train.values.ravel()
y_test = y_test.values.ravel()

# Initialize the RandomForestClassifier without Grid Search CV
fit_rf = RandomForestClassifier(random_state=40, n_estimators=100, max_depth=None, min_samples_split=2, 
                                min_samples_leaf=1, max_features='auto', bootstrap=True)
np.random.seed(40)

# Fit the RandomForestClassifier with the training data
start = time.time()
fit_rf.fit(x_train, y_train)
end = time.time()
print('Time taken to train the model without Grid Search CV: %0.2f seconds' % (end - start))
# Out:
# C:\Users\RISHABH\anaconda3\Lib\site-packages\sklearn\ensemble\_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# Time taken to train the model without Grid Search CV: 0.62 seconds

# %%
# Predict on the test set
predictions_rf = fit_rf.predict(x_test)

# %%
# Calculate and print the accuracy of the model
accuracy_rf_without_cv = accuracy_score(y_test, predictions_rf)
print("Accuracy of model without Grid Search CV: %0.5f" % accuracy_rf_without_cv)
# Out:
# Accuracy of model without Grid Search CV: 0.99853

# %%
# Define parameter grid for GridSearchCV
parameter_grid = {
    'n_estimators': [50, 100, 200],
    'max_depth': [None, 10, 20, 30],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': ['auto', 'sqrt', 'log2'],
    'bootstrap': [True, False]
}

# Initialize RandomForestClassifier
rf_model = RandomForestClassifier(random_state=42)

# Initialize GridSearchCV
cv = GridSearchCV(rf_model, param_grid=parameter_grid, cv=5, scoring='accuracy', n_jobs=-1)

# Fit GridSearchCV
start = time.time()
cv.fit(x_train, y_train)
end = time.time()
print('Time taken to train the model with Grid Search CV: %0.2f seconds' % (end - start))
# Out:
# C:\Users\RISHABH\anaconda3\Lib\site-packages\sklearn\ensemble\_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# Time taken to train the model with Grid Search CV: 285.28 seconds

# %%
# Get best parameters from GridSearchCV
best_params = cv.best_params_
print('Best Parameters using Grid Search \n', best_params)
# Out:
# Best Parameters using Grid Search
#  {'bootstrap': False, 'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}

# %%
# Predict using the best estimator
y_pred = cv.predict(x_test)

# %%
# Calculate accuracy score
accuracy_rf_with_cv = accuracy_score(y_test, y_pred)
print("Accuracy of model with Grid Search CV: %0.5f" % accuracy_rf_with_cv)
# Out:
# Accuracy of model with Grid Search CV: 0.99824

# %%
cv.predict([[329,2.09,1,45.00,12,13.200,70.200]])
# Out:
# C:\Users\RISHABH\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# array([0], dtype=int64)

# %%
# Bar chart to compare accuracies
import matplotlib.pyplot as plt
labels = ['Without Grid Search CV', 'With Grid Search CV']
accuracies = [accuracy_rf_without_cv, accuracy_rf_with_cv]
plt.bar(labels, accuracies, color=['blue', 'green'])
plt.xlabel('Model')
plt.ylabel('Accuracy')
plt.title('Comparison of Model Accuracies')
plt.ylim(0, 1)
plt.show()

# %% [markdown]
# # KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
knn = KNeighborsClassifier(n_neighbors=5)  # you can choose any number of neighbors
knn.fit(x_train, y_train)
y_pred = knn.predict(x_test)
print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9671650542362944

# %%
knn.predict([[329,2.09,1,45.00,12,13.200,70.200]])
# Out:
# C:\Users\RISHABH\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# array([0], dtype=int64)

# %%
from sklearn.model_selection import GridSearchCV
param_grid = {
    'n_neighbors': np.arange(1, 31),
    'weights': ['uniform', 'distance'],
    'metric': ['euclidean', 'manhattan', 'minkowski']
}
grid_search = GridSearchCV(estimator=knn, param_grid=param_grid, cv=5, n_jobs=-1, scoring='accuracy')
grid_search.fit(x_train, y_train)
best_params = grid_search.best_params_
print("Best parameters found: ", best_params)
y_pred = grid_search.best_estimator_.predict(x_test)
print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Best parameters found:  {'metric': 'manhattan', 'n_neighbors': 6, 'weights': 'distance'}
# Accuracy: 0.9739079448841982

# %% [markdown]
# # Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB
nb = GaussianNB()
nb.fit(x_train, y_train)
y_pred = nb.predict(x_test)
print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9551451187335093

# %%
nb.predict([[329,2.09,1,45.00,12,13.200,70.200]])
# Out:
# C:\Users\RISHABH\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GaussianNB was fitted with feature names
#   warnings.warn(
# array([0], dtype=int64)

# %%
# Define the parameter grid
param_grid = {
    'var_smoothing': np.logspace(0, -9, num=100)
}
grid_search = GridSearchCV(estimator=nb, param_grid=param_grid, cv=5, n_jobs=-1, scoring='accuracy')
grid_search.fit(x_train, y_train)
best_params = grid_search.best_params_
print("Best parameters found: ", best_params)
y_pred = grid_search.best_estimator_.predict(x_test)
print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Best parameters found:  {'var_smoothing': 3.5111917342151273e-09}
# Accuracy: 0.9551451187335093

# %% [markdown]
# # SVC

# %%
import numpy as np
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
scaler = StandardScaler()
X_train = scaler.fit_transform(x_train)
X_test = scaler.transform(x_test)
clf = SVC(kernel='linear')
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.2f}")
# Out:
# Accuracy: 0.98

# %%
clf.predict([[329,2.09,1,45.00,12,13.200,70.200]])
# Out:
# array([1], dtype=int64)

# %%
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
svc = SVC()
param_grid = {
    'C': [0.1, 1, 10],
    'gamma': [0.1, 0.01],
    'kernel': ['linear', 'rbf']
}
grid_search = GridSearchCV(estimator=svc, param_grid=param_grid, cv=3, n_jobs=-1, scoring='accuracy')
grid_search.fit(x_train, y_train)
best_params = grid_search.best_params_
print("Best parameters found: ", best_params)
y_pred = grid_search.best_estimator_.predict(x_test)
print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Best parameters found:  {'C': 0.1, 'gamma': 0.1, 'kernel': 'linear'}
# Accuracy: 0.9762532981530343

# %% [markdown]
# # Bar Chart

# %%
import matplotlib.pyplot as plt
import numpy as np

# Accuracy scores
models = ['Logistic Regression', 'Decision Tree', 'Random Forest','KNN','Naive Bayes','SVC']
without_gscv = [0.97, 0.99, 0.99,0.96,0.96,0.98]
with_gscv = [0.97, 0.99, 0.99,0.97,0.95,0.97]

# Setting the positions and width for the bars
bar_width = 0.35
r1 = np.arange(len(models))
r2 = [x + bar_width for x in r1]

# Creating the bar plot
plt.figure(figsize=(10, 6))
plt.bar(r1, without_gscv, color='b', width=bar_width, edgecolor='grey', label='Without GridSearchCV')
plt.bar(r2, with_gscv, color='g', width=bar_width, edgecolor='grey', label='With GridSearchCV')

# Adding labels and title
plt.xlabel('Models', fontweight='bold')
plt.ylabel('Accuracy', fontweight='bold')
plt.title('Model Accuracy Comparison with and without GridSearchCV', fontweight='bold')
plt.xticks([r + bar_width/2 for r in range(len(models))], models)
plt.ylim(0.9, 1.01)

# Adding the legend
plt.legend()

# Adding accuracy labels on top of the bars
for i in range(len(r1)):
    plt.text(r1[i], without_gscv[i] + 0.005, f"{without_gscv[i]:.2f}", ha='center', fontweight='bold')
    plt.text(r2[i], with_gscv[i] + 0.005, f"{with_gscv[i]:.2f}", ha='center', fontweight='bold')

# Displaying the plot
plt.show()

# %%
import pandas as pd

# Create a DataFrame with predictions and expected values
data = {
    'Algorithm': ['Logistic Regression', 'Decision Tree', 'Random Forest','KNN','Naive Bayes','SVC'],
    'Prediction': [0, 0, 0, 0 ,0 ,1],
    'Expected': [0, 0, 0, 0, 0, 0]
}

# Convert the dictionary to a DataFrame
prediction_table = pd.DataFrame(data)

# Display the table
prediction_table
# Out:
#              Algorithm  Prediction  Expected
# 0  Logistic Regression           0         0
# 1        Decision Tree           0         0
# 2        Random Forest           0         0
# 3                  KNN           0         0
# 4          Naive Bayes           0         0
# 5                  SVC           1         0
